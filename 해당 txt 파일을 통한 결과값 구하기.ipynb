# %% [markdown]
# #  파일 입출력

# %%
# 파일 생성

f = open('새파일.txt', 'w')   # 지정되어 있던 경로에 새파일 만들기.
            # 'r' (읽기모드) / 'w' (쓰기모드) $ 기존에 있던 내용을 다 지우고 / 'a' (쓰기모드) $ 마지막에 내용을 추가할때.

# %%
type(f)
# Out:
# _io.TextIOWrapper

# %%
f.close()       # 약속된 절차. (열고 닫고)

# %%
f = open('C:/doit/새파일.txt', 'w')   # 원하는 폴더에 새파일.txt 만들기.

# %%
f.close()

# %%
# 파일을 쓰기모드로 열고 출력값 적기
f = open('./새파일.txt', 'w')

for i in range(1,11):
    data = '%d번째 줄입니다. \n' % i
    f.write(data)
f.close()

# %%
for i in range(1,11):
    data = '%d번째 줄입니다. \n' % i
    print(data)
# Out:
# 1번째 줄입니다.
#
# 2번째 줄입니다.
#
# 3번째 줄입니다.
#
# 4번째 줄입니다.
#
# 5번째 줄입니다.
#
# 6번째 줄입니다.
#
# 7번째 줄입니다.
#
# 8번째 줄입니다.
#
# 9번째 줄입니다.
#
# 10번째 줄입니다.

# %%
# 외부 파일 읽기.

# %%
f = open('./새파일.txt', 'r')
line = f.readline()   # 가장위에 글만 읽는 함수.
print(line)
f.close()
# Out:
# 1번째 줄입니다.

# %%
f = open('./새파일.txt', 'r')
while True:
    line = f.readline()
    if not line: break         # 비어있으면 거짓으로 인식한다. 즉, 1~10번까지 입력후 정지.
    print(line)
f.close()
# Out:
# 1번째 줄입니다.
#
# 2번째 줄입니다.
#
# 3번째 줄입니다.
#
# 4번째 줄입니다.
#
# 5번째 줄입니다.
#
# 6번째 줄입니다.
#
# 7번째 줄입니다.
#
# 8번째 줄입니다.
#
# 9번째 줄입니다.
#
# 10번째 줄입니다.

# %%
f = open('./새파일.txt', 'r')
lines = f.readlines()               # 옆으로 주루룩 출력된다.
print(lines)
f.close()
# Out:
# ['1번째 줄입니다. \n', '2번째 줄입니다. \n', '3번째 줄입니다. \n', '4번째 줄입니다. \n', '5번째 줄입니다. \n', '6번째 줄입니다. \n', '7번째 줄입니다. \n', '8번째 줄입니다. \n', '9번째 줄입니다. \n', '10번째 줄입니다. \n']

# %%
f = open('./새파일.txt', 'r')
lines = f.read()           # 문자열로 다 출력이 된다.
print(lines)
f.close()
# Out:
# 1번째 줄입니다.
# 2번째 줄입니다.
# 3번째 줄입니다.
# 4번째 줄입니다.
# 5번째 줄입니다.
# 6번째 줄입니다.
# 7번째 줄입니다.
# 8번째 줄입니다.
# 9번째 줄입니다.
# 10번째 줄입니다.

# %%
f = open('./새파일.txt', 'a')
for i in range(11,21):
    data ='%d번째 줄입니다.\n' %i
    f.write(data)
f.close()

# %%
sample = '123940!가나@다라#마바$ab%cd^eA&BC&D*E()'
result = ''
for i in sample:
    if i.isalnum():
        result += i
print(result)

# %%
file array = ['C:/doit/20191223_북한방송_주요내용.txt','C:/doit/20191224_북한방송_주요내용.txt',
             'C:/doit/20191225_북한방송_주요내용.txt','C:/doit/20191226_북한방송_주요내용.txt',
             'C:/doit/20191227_북한방송_주요내용.txt','C:/doit/20191228_북한방송_주요내용.txt',
             'C:/doit/20191229_북한방송_주요내용.txt','C:/doit/20191230_북한방송_주요내용.txt',
            ]

g = open('file array', 'r')
line = g.readline()   
print(line)
f.close()
# Out:
#   File "<ipython-input-87-73bd120fa792>", line 1
#     'file array' = ['C:/doit/20191223_북한방송_주요내용.txt','C:/doit/20191224_북한방송_주요내용.txt',
#                                                                                       ^
# SyntaxError: can't assign to literal

# %%
list
for i in range(23, 31):
    f = open(% i, 'r')
    lines = f.readlines()
    list.append(f)
print(list)
# Out:
# [<_io.TextIOWrapper name='c:/doit/20191223_북한방송_주요내용.txt' mode='r' encoding='cp949'>, <_io.TextIOWrapper name='c:/doit/20191224_북한방송_주요내용.txt' mode='r' encoding='cp949'>, <_io.TextIOWrapper name='c:/doit/20191225_북한방송_주요내용.txt' mode='r' encoding='cp949'>, <_io.TextIOWrapper name='c:/doit/20191226_북한방송_주요내용.txt' mode='r' encoding='cp949'>, <_io.TextIOWrapper name='c:/doit/20191227_북한방송_주요내용.txt' mode='r' encoding='cp949'>, <_io.TextIOWrapper name='c:/doit/20191228_북한방송_주요내용.txt' mode='r' encoding='cp949'>, <_io.TextIOWrapper name='c:/doit/20191229_북한방송_주요내용.txt' mode='r' encoding='cp949'>, <_io.TextIOWrapper name='c:/doit/20191230_북한방송_주요내용.txt' mode='r' encoding='cp949'>, <_io.TextIOWrapper name='c:/doit/20191223_북한방송_주요내용.txt' mode='r' encoding='cp949'>, <_io.TextIOWrapper name='c:/doit/20191224_북한방송_주요내용.txt' mode='r' encoding='cp949'>, <_io.TextIOWrapper name='c:/doit/20191225_북한방송_주요내용.txt' mode='r' encoding='cp949'>, <_io.TextIOWrapper name='c:/doit/20191226_북한방송_주요내용.txt' mode=
# ...

# %%
f =open('C:/doit/20191223_북한방송_주요내용.txt','r')
lines = f.readlines()               # 옆으로 주루룩 출력된다.
print(lines)
f.close()
# Out:
# ['2019.12.23.(월) \n', '\n', '\n', '정세분석국\n', '\n', '북한방송 \n', '주요논조 \n', '\n', '\n', '(정세분석총괄과) \n', '\n', '\n', '대남동향대남동향\n', 'o특이동향 없음.\n', '대내동향대내동향o최고인민회의 상임위 정령 제182호(12.11.),모범적인 단위들에 3대혁명 \n', '붉은기를 수여함에 대한 정령 발표(12.22,중앙방송)\n', 'o전국 청년학생들의 백두산지구 혁명전적지 답사행군대,22일 무포 \n', '숙영지와 대홍단 혁명전적지 답사(12.22,중앙통신)\n', 'o임업성,겨울철 통나무 생산을 늘리기 위한 경제조직사업을 진행 \n', '(12.22,평양방송)\n', '*평양철도국체육단,감독 연구사들의 자질향상사업 주력(12.22,중앙방송)\n', 'o北,매 시간 ‘黨 중앙군사위 제7기 제3차 확대회의’진행 소식 보도 \n', '(12.22,중앙방송·평양방송)\n', 'o특이동향 없음.\n', '대외동향대외동향\n', '-1\n', '\n', '\n', '\x0c\n']

# %%
list = []

file array = ['C:/doit/20191223_북한방송_주요내용.txt','C:/doit/20191224_북한방송_주요내용.txt',
             'C:/doit/20191225_북한방송_주요내용.txt','C:/doit/20191226_북한방송_주요내용.txt',
             'C:/doit/20191227_북한방송_주요내용.txt','C:/doit/20191228_북한방송_주요내용.txt',
             'C:/doit/20191229_북한방송_주요내용.txt','C:/doit/20191230_북한방송_주요내용.txt',]
for i in file array:
    f = open(file arry,'r')
lines = f.readlines()
print(lines)
f.close
# Out:
#   File "<ipython-input-94-59bfd6f3f85c>", line 3
#     file array = ['C:/doit/20191223_북한방송_주요내용.txt','C:/doit/20191224_북한방송_주요내용.txt',
#              ^
# SyntaxError: invalid syntax

# %%
list = []
for i in range(23, 31):
    f = open('c:/jeong/201912%d_북한방송_주요내용.txt'% i, 'r')
    list.append(f)

# %%
list = []
for i in range(23, 31):
    f = open('c:/doit/201912%d_북한방송_주요내용.txt'% i, 'r')
print(f)
# Out:
# <_io.TextIOWrapper name='c:/doit/20191230_북한방송_주요내용.txt' mode='r' encoding='cp949'>

# %%
for i in range(23, 31):
    f = open('c:/doit/201912%d_북한방송_주요내용.txt'% i, 'r')
    g = f.read()
    print(g)
# Out:
# 2019.12.23.(월)
#
#
# 정세분석국
#
# 북한방송
# 주요논조
#
#
# (정세분석총괄과)
#
#
# 대남동향대남동향
# o특이동향 없음.
# 대내동향대내동향o최고인민회의 상임위 정령 제182호(12.11.),모범적인 단위들에 3대혁명
# 붉은기를 수여함에 대한 정령 발표(12.22,중앙방송)
# o전국 청년학생들의 백두산지구 혁명전적지 답사행군대,22일 무포
# 숙영지와 대홍단 혁명전적지 답사(12.22,중앙통신)
# o임업성,겨울철 통나무 생산을 늘리기 위한 경제조직사업을 진행
# (12.22,평양방송)
# *평양철도국체육단,감독 연구사들의 자질향상사업 주력(12.22,중앙방송)
# o北,매 시간 ‘黨 중앙군사위 제7기 제3차 확대회의’진행 소식 보도
# (12.22,중앙방송·평양방송)
# o특이동향 없음.
# 대외동향대외동향
# -1
#
#
#
#
# 2019. 12. 24.(화)
#
# 정세분석국
#
# 북한방송
# 주요논조
#
#
# (정
# 세
# 분
# 석
# 총
# 괄
# 과
# )
#
#
# 대남동향대남동향
# o 특이동향 없음.
# 대내동향대내동향
# o 중앙동물원에 올해 3천여 마리의 동물들이 증가(12.24, 중앙방송)
# o 전국청년학생들의 백두산지구 혁명전적지답사행군대, 12월 23일
# 양강도 삼지연시 소재 김정일 동상 앞 교양마당에서 ‘김정은 위원장
# 에게 보내는 편지채택모임’ 진행(12.23, 중앙통신·중앙방송)
# o“백두의 혁명전통은 우리 혁명의 개척과 더불어 창조되고 끊임없이
# 계승 발전되어온 조선 혁명의 유일무이한 전통이며 우리 혁명의 모든
# 단계, 모든 형태의 투쟁에서 불멸의 생명력을 과시한 힘 있는 무기”
# 라며 “사회주의 건설이 더욱 심화되고 있는 오늘 전체 인민을 백두의
# 혁명전통으로 철저히 무장시키기 위한 교양 사업을 더욱 강도 높이
# 벌이는 것은 중차대한 문제로, 전략적 과업으로 나서고 있다”고 강조
# ...

# %%
for i in range(23, 31):
    f = open('c:/doit/201912%d_북한방송_주요내용.txt'% i, 'r')
    read = f.read()
    split = read.split()
    
    wordcount = {}
    
    for word in wordlist:
        wordcount[word] = wordcount.ger(word,0)+1
        keys = sorted(wordcount.keys())
    for word in keys:
    
        print(word + ':' + str(wordcount[word]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-125-bd45d4eab2e1> in <module>
#       6     wordcount = { }
#       7
# ----> 8     for word in wordlist:
#       9         wordcount[word] = wordcount.ger(word,0)+1
#      10         keys = sorted(wordcount.keys())
#
# NameError: name 'wordlist' is not defined

# %%
for i in range(23, 31):
    f = open('c:/doit/201912%d_북한방송_주요내용.txt'% i, 'r')
    read = f.read()
    split = read.split()
    print(split)
# Out:
# ['2019.12.23.(월)', '정세분석국', '북한방송', '주요논조', '(정세분석총괄과)', '대남동향대남동향', 'o특이동향', '없음.', '대내동향대내동향o최고인민회의', '상임위', '정령', '제182호(12.11.),모범적인', '단위들에', '3대혁명', '붉은기를', '수여함에', '대한', '정령', '발표(12.22,중앙방송)', 'o전국', '청년학생들의', '백두산지구', '혁명전적지', '답사행군대,22일', '무포', '숙영지와', '대홍단', '혁명전적지', '답사(12.22,중앙통신)', 'o임업성,겨울철', '통나무', '생산을', '늘리기', '위한', '경제조직사업을', '진행', '(12.22,평양방송)', '*평양철도국체육단,감독', '연구사들의', '자질향상사업', '주력(12.22,중앙방송)', 'o北,매', '시간', '‘黨', '중앙군사위', '제7기', '제3차', '확대회의’진행', '소식', '보도', '(12.22,중앙방송·평양방송)', 'o특이동향', '없음.', '대외동향대외동향', '-1']
# ...

# %%
gjf = []
wordcount = {}
for i in range(23, 31):
    f = open('c:/doit/201912%d_북한방송_주요내용.txt'% i, 'r')
    read = f.read()
    wordlist = read.split()
    gjf += wordlist

    
for i in range(len(gjf)):
    for gjf[i] in gjf:
        wordcount[word] = wordcount.get(word, 0) +1
        keys = sorted(wordcount.keys())

for word in keys:
    print(word + ':' + str(wordcount[word]))
# Out:
# 힘:4955076

# %%
sorted([5,4,3,2,1])
# Out:
# [1, 2, 3, 4, 5]

# %%
sorted({1:'d', 2:'b', 3:'b'})
# Out:
# [1, 2, 3]

# %%
sorted

# %%
f = open('c:/doit/2019125_북한방송_주요내용.txt', 'r')
read = f.read()
wordlist = read.split()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-162-7b42af8a2947> in <module>
# ----> 1 f = open('c:/doit/2019125_북한방송_주요내용.txt', 'r')
#       2 read = f.read()
#       3 wordlist = read.split()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'c:/doit/2019125_북한방송_주요내용.txt'

# %%
import os            # 폴더 안에 있는 파일값을 도출할때.
path = "./"
file_list = os.listdir(path)
file_list_py = [file for file in file_list if file.endswith(".txt")]   # 끝짜리 .txt 자리만 도출하기.
print(file_list_py)
